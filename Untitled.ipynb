# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/Users/yuya/.pyenv/versions/anaconda3-2020.07/envs/pyst/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
# フォントのキャッシュを削除
import matplotlib.font_manager as fm
fm._rebuild()

# %%
# 日本語が表示できるかのテスト
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 3], [2, 4])
ax.set_title('test')

plt.show()
